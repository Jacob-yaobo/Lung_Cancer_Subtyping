# %%
'''
 # @ Author: Yaobo Jia
 # @ Create Time: 2025-05-27 14:15:28
 # @ Modified by: Yaobo Jia
 # @ Modified time: 2025-05-27 14:48:57
 # @ Description: 不同模态的nifti数据的预处理工作；
 # 完成数据的预处理，resample使得所有数据的spacing统一；
 # 同时对同一组数据的不同模态（CT、PET）取得相同的size
 '''
import os
import numpy as np
import nibabel as nib
import pandas as pd
from scipy.ndimage import zoom

def load_nifti(file_path):
    img = nib.load(file_path)
    data = img.get_fdata()
    affine = img.affine
    spacing = img.header.get_zooms()
    
    return data, affine, spacing

def save_nifti(data, affine, path):
    img = nib.Nifti1Image(data, affine)
    nib.save(img, path)

def resample(data, in_spacing, tgt_spacing, affine, order=1):
    if np.allclose(in_spacing, tgt_spacing):
        return data, affine
    
    zoom_factors = in_spacing / tgt_spacing
    out = zoom(data, zoom_factors, order=order)
    directions = affine[:3, :3] / np.linalg.norm(affine[:3, :3], axis=0)
    new_affine = affine.copy()
    new_affine[:3, :3] = directions @ np.diag(tgt_spacing)
    return out, new_affine

def get_bb_min_max(data, threshold=0):
    coords = np.array(np.where(data > threshold))
    return coords.min(axis=1), coords.max(axis=1)
    
def transform_coordinates(center, source_affine, target_affine):
	"""Transform coordinates from PET space to CT space."""
	center_world = nib.affines.apply_affine(source_affine, center)  # PET → World
	center_ct = nib.affines.apply_affine(np.linalg.inv(target_affine), center_world)  # World → CT
	return np.round(center_ct).astype(int)  # Convert to integer voxel indices

def crop(pet, ct, pet_affine, ct_affine):
    min_pet, max_pet = get_bb_min_max(pet, threshold=0)
    min_ct, max_ct = get_bb_min_max(ct, threshold=-1000) 
    # 将pet的bounding box坐标转移到ct坐标系下
    min_pet_ct = transform_coordinates(min_pet, pet_affine, ct_affine)
    max_pet_ct = transform_coordinates(max_pet, pet_affine, ct_affine)
    # compute overlap bounding box
    over_min = np.maximum(min_pet_ct, min_ct)
    over_max = np.minimum(max_pet_ct, max_ct) 
    # crop ct in ct coordinate
    ct_crop = ct[
	    over_min[0]:over_max[0]+1,
        over_min[1]:over_max[1]+1,
        over_min[2]:over_max[2]+1
    ]
    # transform bonuding box from ct coordinate to pet coordinate
    min_ct2pet = transform_coordinates(over_min, ct_affine, pet_affine)
    max_ct2pet = transform_coordinates(over_max, ct_affine, pet_affine)
    # crop pet in pet coordinate
    pet_crop = pet[
        min_ct2pet[0]:max_ct2pet[0]+1,
        min_ct2pet[1]:max_ct2pet[1]+1,
        min_ct2pet[2]:max_ct2pet[2]+1
    ]

    return pet_crop, ct_crop, over_min, over_max, min_ct2pet, max_ct2pet
    

def process_case(ct_path, pet_path, lung_path, mask_path):
    pet, pet_affine, pet_spacing = load_nifti(pet_path)
    ct, ct_affine, ct_spacing = load_nifti(ct_path)
    lung, _, _ = load_nifti(lung_path)
    mask, _, _ = load_nifti(mask_path)

    pet_resampled, pet_resampled_affine = resample(pet, pet_spacing, TARGET_SPACING, pet_affine)
    ct_resampled, ct_resampled_affine = resample(ct, ct_spacing, TARGET_SPACING, ct_affine)
    lung_resampled, _ = resample(lung, ct_spacing, TARGET_SPACING, ct_affine, order=0)
    mask_resampled, _ = resample(mask, pet_spacing, TARGET_SPACING, pet_affine, order=0)

    pet_cropped, ct_cropped, ct_min, ct_max, pet_min, pet_max = crop(pet_resampled, ct_resampled, pet_resampled_affine, ct_resampled_affine)
    lung_cropped = lung_resampled[
	    ct_min[0]:ct_max[0]+1,
        ct_min[1]:ct_max[1]+1,
        ct_min[2]:ct_max[2]+1
    ]
    mask_cropped = mask_resampled[
        pet_min[0]:pet_max[0]+1,
        pet_min[1]:pet_max[1]+1,
        pet_min[2]:pet_max[2]+1
    ]
    # in new affine: set origin = 0
    affine = pet_resampled_affine.copy()
    affine[:3, 3] = 0

    return pet_cropped, ct_cropped, lung_cropped, mask_cropped, affine


if __name__ == '__main__':
    BASE = '/mnt/HDD_1/FDG/LungCancer_Subtyping'
    TARGET_SPACING = np.array([4.07283, 4.07283, 3.0], dtype=float)
    centers = ['Neimeng_nifti_425', 'AKH_nifti_637']

    for center in centers:
        df = pd.read_excel(f'data/{center}_image_info.xlsx', sheet_name='Sheet1', dtype={'PID': str})
        for pid in df['PID']:
            print(f'[INFO] Processing {center} {pid}')
            root = f'{BASE}/data/nifti/{center}/{pid}'
            ct_path  = f'{root}/CT.nii.gz'
            pet_path = f'{root}/PET.nii.gz'
            lung_path = f'data/lung-seg/{center}/{pid}/lung.nii.gz'
            # lesion mask 可能文件名不固定
            lesion_dir = f'{BASE}/data/lesion_seg/{center}'
            mask_path  = next((os.path.join(lesion_dir, f)
                               for f in os.listdir(lesion_dir)
                               if f.startswith(pid) and f.endswith('.nii.gz')), None)
            if mask_path is None:
                print(f'  [WARN] mask missing, skip'); continue

            pet_cropped, ct_cropped, lung_cropped, mask_cropped, affine = process_case(ct_path, pet_path, lung_path, mask_path)

            out_dir = f'data/preprocessed/{center}/{pid}'
            os.makedirs(out_dir, exist_ok=True)
            save_nifti(ct_cropped, affine, f'{out_dir}/CT_rs.nii.gz')
            save_nifti(pet_cropped, affine, f'{out_dir}/PET_rs.nii.gz')
            save_nifti(mask_cropped, affine, f'{out_dir}/Mask_rs.nii.gz')
            save_nifti(lung_cropped, affine, f'{out_dir}/Lung_rs.nii.gz')

# %% [markdown]
# ## 重采样之后的数据位置
# CT： /mnt/HDD_1/FDG/LungCancer_Subtyping/data/processed_yaobo/resampled_nifti/{center}/{PID}/CT.nii.gz
# PET： /mnt/HDD_1/FDG/LungCancer_Subtyping/data/processed_yaobo/resampled_nifti/{center}/{PID}/PET.nii.gz
# lung mask:  /mnt/HDD_1/FDG/LungCancer_Subtyping/data/processed_yaobo/lung_seg/{center}/{PID}/lung_seg.nii.gz
# lesion mask:  /mnt/HDD_1/FDG/LungCancer_Subtyping/data/processed_yaobo/lesion_seg/{center}/{PID}/lesion_seg.nii.gz
#
# ## 完成文件完整性检查

# %%
# 文件完整性检查
import pandas as pd
import os
from pathlib import Path
from collections import defaultdict

def check_file_integrity():
    """
    检查重采样后数据的完整性
    """
    print("=== 重采样数据文件完整性检查 ===")
    
    # 读取metadata
    metadata_path = "metadata/metadata_filtered.csv"
    metadata_df = pd.read_csv(metadata_path, dtype={'PID': str})
    
    print(f"Metadata中的样本数: {len(metadata_df)}")
    print(f"包含的中心: {metadata_df['center'].value_counts().to_dict()}")
    
    # 定义数据路径模板
    data_paths = {
        'CT': '/mnt/HDD_1/FDG/LungCancer_Subtyping/data/processed_yaobo/resampled_nifti/{center}/{pid}/CT.nii.gz',
        'PET': '/mnt/HDD_1/FDG/LungCancer_Subtyping/data/processed_yaobo/resampled_nifti/{center}/{pid}/PET.nii.gz',
        'lung_mask': '/mnt/HDD_1/FDG/LungCancer_Subtyping/data/processed_yaobo/lung_seg/{center}/{pid}/lung_seg.nii.gz',
        'lesion_mask': '/mnt/HDD_1/FDG/LungCancer_Subtyping/data/processed_yaobo/lesion_seg/{center}/{pid}/lesion_seg.nii.gz'
    }
    
    # 统计结果
    complete_samples = []
    incomplete_samples = []
    missing_files = defaultdict(list)
    
    print(f"\n=== 检查metadata中的样本 ===")
    
    for idx, row in metadata_df.iterrows():
        center = row['center']
        pid = row['PID']
        
        sample_status = {
            'center': center,
            'pid': pid,
            'files': {}
        }
        
        all_files_exist = True
        
        for modality, path_template in data_paths.items():
            file_path = path_template.format(center=center, pid=pid)
            exists = os.path.exists(file_path)
            sample_status['files'][modality] = exists
            
            if not exists:
                all_files_exist = False
                missing_files[modality].append(f"{center}/{pid}")
        
        if all_files_exist:
            complete_samples.append(sample_status)
        else:
            incomplete_samples.append(sample_status)
    
    # 输出统计结果
    print(f"\n=== 完整性统计 ===")
    print(f"完整样本数: {len(complete_samples)} / {len(metadata_df)} ({len(complete_samples)/len(metadata_df)*100:.1f}%)")
    print(f"不完整样本数: {len(incomplete_samples)}")
    
    # 按模态统计缺失文件
    print(f"\n=== 各模态缺失统计 ===")
    for modality, missing_list in missing_files.items():
        print(f"{modality}: 缺失 {len(missing_list)} 个文件")
        if len(missing_list) <= 10:
            for missing in missing_list:
                print(f"  - {missing}")
        else:
            for missing in missing_list[:5]:
                print(f"  - {missing}")
            print(f"  ... 还有 {len(missing_list) - 5} 个缺失文件")
    
    # 按中心统计
    print(f"\n=== 各中心完整性统计 ===")
    for center in metadata_df['center'].unique():
        center_samples = metadata_df[metadata_df['center'] == center]
        center_complete = [s for s in complete_samples if s['center'] == center]
        print(f"{center}: {len(center_complete)} / {len(center_samples)} 完整 ({len(center_complete)/len(center_samples)*100:.1f}%)")
    
    return complete_samples, incomplete_samples, missing_files

# 执行检查
complete_samples, incomplete_samples, missing_files = check_file_integrity()
# Out:
# === 重采样数据文件完整性检查 ===
# Metadata中的样本数: 1030
# 包含的中心: {'AKH_nifti_637': 618, 'Neimeng_nifti_425': 412}
#
# === 检查metadata中的样本 ===
#
# === 完整性统计 ===
# 完整样本数: 1030 / 1030 (100.0%)
# 不完整样本数: 0
#
# === 各模态缺失统计 ===
#
# === 各中心完整性统计 ===
# AKH_nifti_637: 618 / 618 完整 (100.0%)
# Neimeng_nifti_425: 412 / 412 完整 (100.0%)

# %%
# 检查文件系统中存在但metadata中缺失的样本
def check_extra_files():
    """
    检查文件系统中存在但metadata中没有记录的样本
    """
    print(f"\n=== 检查额外文件 (存在于文件系统但不在metadata中) ===")
    
    # 读取metadata中的样本列表
    metadata_df = pd.read_csv("metadata/metadata_filtered.csv", dtype={'PID': str})
    metadata_samples = set()
    for _, row in metadata_df.iterrows():
        metadata_samples.add(f"{row['center']}/{row['PID']}")
    
    # 定义要检查的根目录
    base_dirs = {
        'resampled_nifti': '/mnt/HDD_1/FDG/LungCancer_Subtyping/data/processed_yaobo/resampled_nifti',
        'lung_seg': '/mnt/HDD_1/FDG/LungCancer_Subtyping/data/processed_yaobo/lung_seg',
        'lesion_seg': '/mnt/HDD_1/FDG/LungCancer_Subtyping/data/processed_yaobo/lesion_seg'
    }
    
    # 检查每个目录
    extra_samples = defaultdict(set)
    
    for dir_type, base_dir in base_dirs.items():
        if not os.path.exists(base_dir):
            print(f"⚠ 目录不存在: {base_dir}")
            continue
            
        print(f"\n检查目录: {dir_type}")
        
        # 遍历中心目录
        for center in ['AKH_nifti_637', 'Neimeng_nifti_425']:
            center_dir = os.path.join(base_dir, center)
            
            if not os.path.exists(center_dir):
                print(f"  ⚠ 中心目录不存在: {center_dir}")
                continue
            
            # 遍历患者目录
            try:
                for pid in os.listdir(center_dir):
                    pid_dir = os.path.join(center_dir, pid)
                    if os.path.isdir(pid_dir):
                        sample_key = f"{center}/{pid}"
                        
                        # 检查是否在metadata中
                        if sample_key not in metadata_samples:
                            extra_samples[dir_type].add(sample_key)
                            print(f"    + 额外样本: {sample_key}")
            except PermissionError:
                print(f"  ❌ 无权限访问: {center_dir}")
            except Exception as e:
                print(f"  ❌ 读取错误: {center_dir} - {e}")
    
    # 汇总额外样本
    all_extra_samples = set()
    for dir_type, samples in extra_samples.items():
        all_extra_samples.update(samples)
    
    print(f"\n=== 额外样本汇总 ===")
    if all_extra_samples:
        print(f"发现 {len(all_extra_samples)} 个额外样本 (存在于文件系统但不在metadata中):")
        for sample in sorted(all_extra_samples):
            print(f"  - {sample}")
            
        # 按中心统计
        print(f"\n按中心统计额外样本:")
        center_extra = defaultdict(int)
        for sample in all_extra_samples:
            center = sample.split('/')[0]
            center_extra[center] += 1
        
        for center, count in center_extra.items():
            print(f"  {center}: {count} 个额外样本")
    else:
        print("✓ 没有发现额外样本，所有文件系统中的样本都在metadata中有记录")
    
    return extra_samples

# 执行额外文件检查
extra_samples = check_extra_files()
# Out:
# === 检查额外文件 (存在于文件系统但不在metadata中) ===
#
# 检查目录: resampled_nifti
#     + 额外样本: AKH_nifti_637/GRUJA-LINA20230323
#     + 额外样本: AKH_nifti_637/HOFER-EMMERICH20150224
#     + 额外样本: AKH_nifti_637/AHAMER-GERHARD20240213
#     + 额外样本: AKH_nifti_637/STARCH-JOHANN-DI20230810
#     + 额外样本: AKH_nifti_637/SAVIC-PERO20090924
#     + 额外样本: AKH_nifti_637/CZERNY-JOHANN20190801
#     + 额外样本: AKH_nifti_637/GEBAUER-GABRIELE20100929
#     + 额外样本: AKH_nifti_637/HOBUSCH-DIETHARD20100817
#     + 额外样本: AKH_nifti_637/REINER-ERNST20220504
#     + 额外样本: AKH_nifti_637/TORDAY-ILSE-MARIA20110308
#     + 额外样本: AKH_nifti_637/PUTZ-THERESIA20230831
#     + 额外样本: AKH_nifti_637/GINDL-PFLANZ-DIANA20230814
#     + 额外样本: AKH_nifti_637/HAJRULA-CENGIZ20210223
#     + 额外样本: AKH_nifti_637/ERISTAVI-DAVID20091022
#     + 额外样本: AKH_nifti_637/VASAROS-BRIGITTA20100315
#     + 额外样本: Neimeng_nifti_425/406
#     + 额外样本: Neimeng_nifti_425/320
#     + 额外样本: Neimeng_nifti_425/270
#     + 额外样本: Neimeng_nifti_425/156
#     + 额外样本: Neimeng_nifti_425/257
#
#   - AKH_nifti_637/HAJRULA-CENGIZ20210223
#   - AKH_nifti_637/HOBUSCH-DIETHARD20100817
#   - AKH_nifti_637/HOFER-EMMERICH20150224
#   - AKH_nifti_637/PUTZ-THERESIA20230831
#   - AKH_nifti_637/REINER-ERNST20220504
#   - AKH_nifti_637/SAVIC-PERO20090924
#   - AKH_nifti_637/STARCH-JOHANN-DI20230810
#   - AKH_nifti_637/TORDAY-ILSE-MARIA20110308
#   - AKH_nifti_637/VASAROS-BRIGITTA20100315
#   - Neimeng_nifti_425/156
#   - Neimeng_nifti_425/257
#   - Neimeng_nifti_425/270
#   - Neimeng_nifti_425/320
#   - Neimeng_nifti_425/406
#
# 按中心统计额外样本:
#   AKH_nifti_637: 15 个额外样本
#   Neimeng_nifti_425: 5 个额外样本

# %%
# 生成详细的完整性报告
def generate_integrity_report(complete_samples, incomplete_samples, missing_files, extra_samples):
    """
    生成详细的完整性报告并保存
    """
    print(f"\n=== 生成完整性报告 ===")
    
    # 创建详细报告DataFrame
    all_samples = []
    
    # 添加完整样本
    for sample in complete_samples:
        all_samples.append({
            'center': sample['center'],
            'PID': sample['pid'],
            'status': 'complete',
            'CT': True,
            'PET': True,
            'lung_mask': True,
            'lesion_mask': True,
            'missing_modalities': ''
        })
    
    # 添加不完整样本
    for sample in incomplete_samples:
        missing_mods = []
        for modality, exists in sample['files'].items():
            if not exists:
                missing_mods.append(modality)
        
        all_samples.append({
            'center': sample['center'],
            'PID': sample['pid'],
            'status': 'incomplete',
            'CT': sample['files']['CT'],
            'PET': sample['files']['PET'],
            'lung_mask': sample['files']['lung_mask'],
            'lesion_mask': sample['files']['lesion_mask'],
            'missing_modalities': ', '.join(missing_mods)
        })
    
    # 创建DataFrame并保存
    report_df = pd.DataFrame(all_samples)
    report_path = "metadata/file_integrity_report.csv"
    report_df.to_csv(report_path, index=False)
    
    print(f"✓ 完整性报告已保存: {report_path}")
    
    # 生成summary统计
    print(f"\n=== 最终统计汇总 ===")
    total_metadata_samples = len(complete_samples) + len(incomplete_samples)
    print(f"Metadata中的总样本数: {total_metadata_samples}")
    print(f"完整样本数: {len(complete_samples)} ({len(complete_samples)/total_metadata_samples*100:.1f}%)")
    print(f"不完整样本数: {len(incomplete_samples)} ({len(incomplete_samples)/total_metadata_samples*100:.1f}%)")
    
    # 各模态文件存在率
    print(f"\n各模态文件存在率:")
    modalities = ['CT', 'PET', 'lung_mask', 'lesion_mask']
    for modality in modalities:
        existing_count = report_df[modality].sum()
        print(f"  {modality}: {existing_count}/{total_metadata_samples} ({existing_count/total_metadata_samples*100:.1f}%)")
    
    # 额外文件统计
    total_extra = sum(len(samples) for samples in extra_samples.values())
    if total_extra > 0:
        print(f"\n额外文件 (不在metadata中): {total_extra} 个样本")
    
    # 保存额外文件列表
    if total_extra > 0:
        extra_df_data = []
        for dir_type, samples in extra_samples.items():
            for sample in samples:
                center, pid = sample.split('/')
                extra_df_data.append({
                    'center': center,
                    'PID': pid,
                    'found_in_directory': dir_type
                })
        
        if extra_df_data:
            extra_df = pd.DataFrame(extra_df_data)
            extra_path = "metadata/extra_files_report.csv"
            extra_df.to_csv(extra_path, index=False)
            print(f"✓ 额外文件报告已保存: {extra_path}")
    
    return report_df

# 生成报告
integrity_report = generate_integrity_report(complete_samples, incomplete_samples, missing_files, extra_samples)

# 显示前几行报告
print(f"\n=== 完整性报告预览 ===")
print(integrity_report.head(10))
# Out:
# === 生成完整性报告 ===
# ✓ 完整性报告已保存: metadata/file_integrity_report.csv
#
# === 最终统计汇总 ===
# Metadata中的总样本数: 1030
# 完整样本数: 1030 (100.0%)
# 不完整样本数: 0 (0.0%)
#
# 各模态文件存在率:
#   CT: 1030/1030 (100.0%)
#   PET: 1030/1030 (100.0%)
#   lung_mask: 1030/1030 (100.0%)
#   lesion_mask: 1030/1030 (100.0%)
#
# 额外文件 (不在metadata中): 60 个样本
# ✓ 额外文件报告已保存: metadata/extra_files_report.csv
#
# === 完整性报告预览 ===
#           center                          PID    status    CT   PET  \
# 0  AKH_nifti_637   ABDALLA-ADEL-AHMED20091023  complete  True  True
# 1  AKH_nifti_637         ABT-BRIGITTE20160818  complete  True  True
# 2  AKH_nifti_637         ADAMEK-KARIN20211124  complete  True  True
# 3  AKH_nifti_637        AHMED-MOHAMED20230731  complete  True  True
# 4  AKH_nifti_637         AHMEDI-NAZIF20230111  complete  True  True
# 5  AKH_nifti_637  ALIMANY-RAMOS-MARIA20141007  complete  True  True
# 6  AKH_nifti_637     ANDABAKA-MARIJAN20091229  complete  True  True
# 7  AKH_nifti_637    ANSARI-MEHR-AZITA20141216  complete  True  True
# 8  AKH_nifti_637       ANTIC-PRVOSLAV20150826  complete  True  True
# 9  AKH_nifti_637       ANTIC-SLOBODAN20150908  complete  True  True
#
#    lung_mask  lesion_mask missing_modalities
# 0       True         True
# 1       True         True
# 2       True         True
# 3       True         True
# 4       True         True
# 5       True         True
# 6       True         True
# 7       True         True
# 8       True         True
# 9       True         True

# %%
# 检查额外文件的完整性并在原始metadata中查找
def check_extra_files_completeness():
    """
    检查额外文件是否为完整的四个模态，并在原始metadata中查找对应信息
    """
    print("=== 检查额外文件的完整性 ===")
    
    # 从之前的结果获取额外样本列表
    all_extra_samples = set()
    for dir_type, samples in extra_samples.items():
        all_extra_samples.update(samples)
    
    print(f"发现的额外样本总数: {len(all_extra_samples)}")
    
    # 定义数据路径模板
    data_paths = {
        'CT': '/mnt/HDD_1/FDG/LungCancer_Subtyping/data/processed_yaobo/resampled_nifti/{center}/{pid}/CT.nii.gz',
        'PET': '/mnt/HDD_1/FDG/LungCancer_Subtyping/data/processed_yaobo/resampled_nifti/{center}/{pid}/PET.nii.gz',
        'lung_mask': '/mnt/HDD_1/FDG/LungCancer_Subtyping/data/processed_yaobo/lung_seg/{center}/{pid}/lung_seg.nii.gz',
        'lesion_mask': '/mnt/HDD_1/FDG/LungCancer_Subtyping/data/processed_yaobo/lesion_seg/{center}/{pid}/lesion_seg.nii.gz'
    }
    
    # 检查每个额外样本的完整性
    complete_extra_samples = []
    incomplete_extra_samples = []
    
    print(f"\n=== 检查额外样本的四模态完整性 ===")
    
    for sample in sorted(all_extra_samples):
        center, pid = sample.split('/')
        
        sample_files = {}
        all_exist = True
        
        for modality, path_template in data_paths.items():
            file_path = path_template.format(center=center, pid=pid)
            exists = os.path.exists(file_path)
            sample_files[modality] = exists
            if not exists:
                all_exist = False
        
        if all_exist:
            complete_extra_samples.append({
                'center': center,
                'pid': pid,
                'files': sample_files
            })
            print(f"✓ 完整: {sample} (四个模态都存在)")
        else:
            incomplete_extra_samples.append({
                'center': center,
                'pid': pid,
                'files': sample_files
            })
            missing = [mod for mod, exists in sample_files.items() if not exists]
            print(f"✗ 不完整: {sample} (缺少: {', '.join(missing)})")
    
    print(f"\n=== 额外样本完整性统计 ===")
    print(f"完整的额外样本: {len(complete_extra_samples)}")
    print(f"不完整的额外样本: {len(incomplete_extra_samples)}")
    
    # 读取原始metadata
    print(f"\n=== 在原始metadata中查找完整的额外样本 ===")
    
    try:
        original_metadata = pd.read_csv("metadata/metadata.csv", dtype={'PID': str})
        print(f"原始metadata样本数: {len(original_metadata)}")
        
        found_in_original = []
        not_found_in_original = []
        
        for sample in complete_extra_samples:
            center = sample['center']
            pid = sample['pid']
            
            # 在原始metadata中查找
            matches = original_metadata[
                (original_metadata['center'] == center) & 
                (original_metadata['PID'] == pid)
            ]
            
            if len(matches) > 0:
                found_in_original.append({
                    'center': center,
                    'pid': pid,
                    'metadata_rows': matches
                })
                print(f"\n✓ 在原始metadata中找到: {center}/{pid}")
                print("对应的完整行信息:")
                for idx, row in matches.iterrows():
                    print(f"  行 {idx}:")
                    for col in matches.columns:
                        print(f"    {col}: {row[col]}")
                    print("  " + "-"*50)
            else:
                not_found_in_original.append({
                    'center': center,
                    'pid': pid
                })
                print(f"\n✗ 在原始metadata中未找到: {center}/{pid}")
        
        print(f"\n=== 原始metadata查找结果汇总 ===")
        print(f"在原始metadata中找到的完整额外样本: {len(found_in_original)}")
        print(f"在原始metadata中未找到的完整额外样本: {len(not_found_in_original)}")
        
        if found_in_original:
            print(f"\n找到的样本列表:")
            for item in found_in_original:
                print(f"  - {item['center']}/{item['pid']}")
        
        if not_found_in_original:
            print(f"\n未找到的样本列表:")
            for item in not_found_in_original:
                print(f"  - {item['center']}/{item['pid']}")
        
        return complete_extra_samples, found_in_original, not_found_in_original
        
    except FileNotFoundError:
        print("❌ 原始metadata文件不存在: metadata/metadata.csv")
        return complete_extra_samples, [], []
    except Exception as e:
        print(f"❌ 读取原始metadata时出错: {e}")
        return complete_extra_samples, [], []

# 执行检查
complete_extra, found_in_meta, not_found_in_meta = check_extra_files_completeness()
# Out:
# === 检查额外文件的完整性 ===
# 发现的额外样本总数: 20
#
# === 检查额外样本的四模态完整性 ===
# ✓ 完整: AKH_nifti_637/AHAMER-GERHARD20240213 (四个模态都存在)
# ✓ 完整: AKH_nifti_637/CZERNY-JOHANN20190801 (四个模态都存在)
# ✓ 完整: AKH_nifti_637/ERISTAVI-DAVID20091022 (四个模态都存在)
# ✓ 完整: AKH_nifti_637/GEBAUER-GABRIELE20100929 (四个模态都存在)
# ✓ 完整: AKH_nifti_637/GINDL-PFLANZ-DIANA20230814 (四个模态都存在)
# ✓ 完整: AKH_nifti_637/GRUJA-LINA20230323 (四个模态都存在)
# ✓ 完整: AKH_nifti_637/HAJRULA-CENGIZ20210223 (四个模态都存在)
# ✓ 完整: AKH_nifti_637/HOBUSCH-DIETHARD20100817 (四个模态都存在)
# ✓ 完整: AKH_nifti_637/HOFER-EMMERICH20150224 (四个模态都存在)
# ✓ 完整: AKH_nifti_637/PUTZ-THERESIA20230831 (四个模态都存在)
# ✓ 完整: AKH_nifti_637/REINER-ERNST20220504 (四个模态都存在)
# ✓ 完整: AKH_nifti_637/SAVIC-PERO20090924 (四个模态都存在)
# ✓ 完整: AKH_nifti_637/STARCH-JOHANN-DI20230810 (四个模态都存在)
# ✓ 完整: AKH_nifti_637/TORDAY-ILSE-MARIA20110308 (四个模态都存在)
# ✓ 完整: AKH_nifti_637/VASAROS-BRIGITTA20100315 (四个模态都存在)
# ✓ 完整: Neimeng_nifti_425/156 (四个模态都存在)
# ✓ 完整: Neimeng_nifti_425/257 (四个模态都存在)
# ✓ 完整: Neimeng_nifti_425/270 (四个模态都存在)
# ✓ 完整: Neimeng_nifti_425/320 (四个模态都存在)
# ✓ 完整: Neimeng_nifti_425/406 (四个模态都存在)
#
# === 额外样本完整性统计 ===
# 完整的额外样本: 20
# 不完整的额外样本: 0
#
# === 在原始metadata中查找完整的额外样本 ===
# 原始metadata样本数: 1066
#
# ✓ 在原始metadata中找到: AKH_nifti_637/AHAMER-GERHARD20240213
# 对应的完整行信息:
#   行 3:
#     center: AKH_nifti_637
#     PID: AHAMER-GERHARD20240213
#     pet_path: /mnt/HDD_1/FDG/LungCancer_Subtyping/data/nifti/AKH_nifti_637/AHAMER-GERHARD20240213/PET.nii.gz
#     ct_path: /mnt/HDD_1/FDG/LungCancer_Subtyping/data/nifti/AKH_nifti_637/AHAMER-GERHARD20240213/CT.nii.gz
#     lung_seg_path: /mnt/HDD_1/FDG/LungCancer_Subtyping/data/processed_yaobo/lung_seg/AKH_nifti_637/AHAMER-GERHARD20240213/lung_seg.nii.gz
#     pet_exists: True
#     ct_exists: True
#     lung_seg_exists: True
#     SUV_ratio: 0.0004484569246485
#     Pathology: LCNEC
#   --------------------------------------------------
#
# ✓ 在原始metadata中找到: AKH_nifti_637/CZERNY-JOHANN20190801
# 对应的完整行信息:
#   行 66:
#     center: AKH_nifti_637
#     PID: CZERNY-JOHANN20190801
#     pet_path: /mnt/HDD_1/FDG/LungCancer_Subtyping/data/nifti/AKH_nifti_637/CZERNY-JOHANN20190801/PET.nii.gz
#     ct_path: /mnt/HDD_1/FDG/LungCancer_Subtyping/data/nifti/AKH_nifti_637/CZERNY-JOHANN20190801/CT.nii.gz
#     lung_seg_path: /mnt/HDD_1/FDG/LungCancer_Subtyping/data/processed_yaobo/lung_seg/AKH_nifti_637/CZERNY-JOHANN20190801/lung_seg.nii.gz
#     pet_exists: True
#     ct_exists: True
#     lung_seg_exists: True
#     SUV_ratio: 0.0004852225762334
#     Pathology: LCNEC
#   --------------------------------------------------
#
# ✓ 在原始metadata中找到: AKH_nifti_637/ERISTAVI-DAVID20091022
# 对应的完整行信息:
#   行 106:
#     center: AKH_nifti_637
#     PID: ERISTAVI-DAVID20091022
#     pet_path: /mnt/HDD_1/FDG/LungCancer_Subtyping/data/nifti/AKH_nifti_637/ERISTAVI-DAVID20091022/PET.nii.gz
#     ct_path: /mnt/HDD_1/FDG/LungCancer_Subtyping/data/nifti/AKH_nifti_637/ERISTAVI-DAVID20091022/CT.nii.gz
#     lung_seg_path: /mnt/HDD_1/FDG/LungCancer_Subtyping/data/processed_yaobo/lung_seg/AKH_nifti_637/ERISTAVI-DAVID20091022/lung_seg.nii.gz
#     pet_exists: True
#     ct_exists: True
#     lung_seg_exists: True
#     SUV_ratio: 0.0006307917678928
#     Pathology: LCCL
#   --------------------------------------------------
#
# ✓ 在原始metadata中找到: AKH_nifti_637/GEBAUER-GABRIELE20100929
# 对应的完整行信息:
#   行 136:
#     center: AKH_nifti_637
#     PID: GEBAUER-GABRIELE20100929
#     pet_path: /mnt/HDD_1/FDG/LungCancer_Subtyping/data/nifti/AKH_nifti_637/GEBAUER-GABRIELE20100929/PET.nii.gz
#     ct_path: /mnt/HDD_1/FDG/LungCancer_Subtyping/data/nifti/AKH_nifti_637/GEBAUER-GABRIELE20100929/CT.nii.gz
#     lung_seg_path: /mnt/HDD_1/FDG/LungCancer_Subtyping/data/processed_yaobo/lung_seg/AKH_nifti_637/GEBAUER-GABRIELE20100929/lung_seg.nii.gz
#     pet_exists: True
#     ct_exists: True
#     lung_seg_exists: True
#     SUV_ratio: 0.0002581255596809
#     Pathology: LCNEC
#   --------------------------------------------------
#
# ✓ 在原始metadata中找到: AKH_nifti_637/GINDL-PFLANZ-DIANA20230814
# 对应的完整行信息:
#   行 141:
#     center: AKH_nifti_637
#     PID: GINDL-PFLANZ-DIANA20230814
#     pet_path: /mnt/HDD_1/FDG/LungCancer_Subtyping/data/nifti/AKH_nifti_637/GINDL-PFLANZ-DIANA20230814/PET.nii.gz
#     ct_path: /mnt/HDD_1/FDG/LungCancer_Subtyping/data/nifti/AKH_nifti_637/GINDL-PFLANZ-DIANA20230814/CT.nii.gz
#     lung_seg_path: /mnt/HDD_1/FDG/LungCancer_Subtyping/data/processed_yaobo/lung_seg/AKH_nifti_637/GINDL-PFLANZ-DIANA20230814/lung_seg.nii.gz
#     pet_exists: True
#     ct_exists: True
#     lung_seg_exists: True
#     SUV_ratio: 0.0004550297003753
#     Pathology: LCNEC
#   --------------------------------------------------
#
# ✓ 在原始metadata中找到: AKH_nifti_637/GRUJA-LINA20230323
# 对应的完整行信息:
#   行 158:
#     center: AKH_nifti_637
#     PID: GRUJA-LINA20230323
#     pet_path: /mnt/HDD_1/FDG/LungCancer_Subtyping/data/nifti/AKH_nifti_637/GRUJA-LINA20230323/PET.nii.gz
#     ct_path: /mnt/HDD_1/FDG/LungCancer_Subtyping/data/nifti/AKH_nifti_637/GRUJA-LINA20230323/CT.nii.gz
#     lung_seg_path: /mnt/HDD_1/FDG/LungCancer_Subtyping/data/processed_yaobo/lung_seg/AKH_nifti_637/GRUJA-LINA20230323/lung_seg.nii.gz
#     pet_exists: True
#     ct_exists: True
#     lung_seg_exists: True
#     SUV_ratio: 0.0008590684615955
#     Pathology: LCNEC
#   --------------------------------------------------
#
# ✓ 在原始metadata中找到: AKH_nifti_637/HAJRULA-CENGIZ20210223
# 对应的完整行信息:
#   行 172:
#     center: AKH_nifti_637
#     PID: HAJRULA-CENGIZ20210223
#     pet_path: /mnt/HDD_1/FDG/LungCancer_Subtyping/data/nifti/AKH_nifti_637/HAJRULA-CENGIZ20210223/PET.nii.gz
#     ct_path: /mnt/HDD_1/FDG/LungCancer_Subtyping/data/nifti/AKH_nifti_637/HAJRULA-CENGIZ20210223/CT.nii.gz
#     lung_seg_path: /mnt/HDD_1/FDG/LungCancer_Subtyping/data/processed_yaobo/lung_seg/AKH_nifti_637/HAJRULA-CENGIZ20210223/lung_seg.nii.gz
#     pet_exists: True
#     ct_exists: True
#     lung_seg_exists: True
#     SUV_ratio: 0.0004165499082934
#     Pathology: LCNEC
#   --------------------------------------------------
#
# ✓ 在原始metadata中找到: AKH_nifti_637/HOBUSCH-DIETHARD20100817
# 对应的完整行信息:
#   行 192:
#     center: AKH_nifti_637
#     PID: HOBUSCH-DIETHARD20100817
#     pet_path: /mnt/HDD_1/FDG/LungCancer_Subtyping/data/nifti/AKH_nifti_637/HOBUSCH-DIETHARD20100817/PET.nii.gz
#     ct_path: /mnt/HDD_1/FDG/LungCancer_Subtyping/data/nifti/AKH_nifti_637/HOBUSCH-DIETHARD20100817/CT.nii.gz
#     lung_seg_path: /mnt/HDD_1/FDG/LungCancer_Subtyping/data/processed_yaobo/lung_seg/AKH_nifti_637/HOBUSCH-DIETHARD20100817/lung_seg.nii.gz
#     pet_exists: True
#     ct_exists: True
#     lung_seg_exists: True
#     SUV_ratio: 0.0004815297415317
#     Pathology: LCNEC
#   --------------------------------------------------
#
# ✓ 在原始metadata中找到: AKH_nifti_637/HOFER-EMMERICH20150224
# 对应的完整行信息:
#   行 193:
#     center: AKH_nifti_637
#     PID: HOFER-EMMERICH20150224
#     pet_path: /mnt/HDD_1/FDG/LungCancer_Subtyping/data/nifti/AKH_nifti_637/HOFER-EMMERICH20150224/PET.nii.gz
#     ct_path: /mnt/HDD_1/FDG/LungCancer_Subtyping/data/nifti/AKH_nifti_637/HOFER-EMMERICH20150224/CT.nii.gz
#     lung_seg_path: /mnt/HDD_1/FDG/LungCancer_Subtyping/data/processed_yaobo/lung_seg/AKH_nifti_637/HOFER-EMMERICH20150224/lung_seg.nii.gz
#     pet_exists: True
#     ct_exists: True
#     lung_seg_exists: True
#     SUV_ratio: 0.0004730324913142
#     Pathology: LCNEC
#   --------------------------------------------------
#
# ✓ 在原始metadata中找到: AKH_nifti_637/PUTZ-THERESIA20230831
# 对应的完整行信息:
#   行 439:
#     center: AKH_nifti_637
#     PID: PUTZ-THERESIA20230831
#     pet_path: /mnt/HDD_1/FDG/LungCancer_Subtyping/data/nifti/AKH_nifti_637/PUTZ-THERESIA20230831/PET.nii.gz
#     ct_path: /mnt/HDD_1/FDG/LungCancer_Subtyping/data/nifti/AKH_nifti_637/PUTZ-THERESIA20230831/CT.nii.gz
#     lung_seg_path: /mnt/HDD_1/FDG/LungCancer_Subtyping/data/processed_yaobo/lung_seg/AKH_nifti_637/PUTZ-THERESIA20230831/lung_seg.nii.gz
#     pet_exists: True
#     ct_exists: True
#     lung_seg_exists: True
#     SUV_ratio: 0.0005403976687919
#     Pathology: LCCL
#   --------------------------------------------------
#
# ✓ 在原始metadata中找到: AKH_nifti_637/REINER-ERNST20220504
# 对应的完整行信息:
#   行 450:
#     center: AKH_nifti_637
#     PID: REINER-ERNST20220504
#     pet_path: /mnt/HDD_1/FDG/LungCancer_Subtyping/data/nifti/AKH_nifti_637/REINER-ERNST20220504/PET.nii.gz
#     ct_path: /mnt/HDD_1/FDG/LungCancer_Subtyping/data/nifti/AKH_nifti_637/REINER-ERNST20220504/CT.nii.gz
#     lung_seg_path: /mnt/HDD_1/FDG/LungCancer_Subtyping/data/processed_yaobo/lung_seg/AKH_nifti_637/REINER-ERNST20220504/lung_seg.nii.gz
#     pet_exists: True
#     ct_exists: True
#     lung_seg_exists: True
#     SUV_ratio: 0.0005570154201104
#     Pathology: LCNEC
#   --------------------------------------------------
#
# ✓ 在原始metadata中找到: AKH_nifti_637/SAVIC-PERO20090924
# 对应的完整行信息:
#   行 481:
#     center: AKH_nifti_637
#     PID: SAVIC-PERO20090924
#     pet_path: /mnt/HDD_1/FDG/LungCancer_Subtyping/data/nifti/AKH_nifti_637/SAVIC-PERO20090924/PET.nii.gz
#     ct_path: /mnt/HDD_1/FDG/LungCancer_Subtyping/data/nifti/AKH_nifti_637/SAVIC-PERO20090924/CT.nii.gz
#     lung_seg_path: /mnt/HDD_1/FDG/LungCancer_Subtyping/data/processed_yaobo/lung_seg/AKH_nifti_637/SAVIC-PERO20090924/lung_seg.nii.gz
#     pet_exists: True
#     ct_exists: True
#     lung_seg_exists: True
#     SUV_ratio: 0.0005306924228859
#     Pathology: LCNEC
#   --------------------------------------------------
#
# ✓ 在原始metadata中找到: AKH_nifti_637/STARCH-JOHANN-DI20230810
# 对应的完整行信息:
#   行 529:
#     center: AKH_nifti_637
#     PID: STARCH-JOHANN-DI20230810
#     pet_path: /mnt/HDD_1/FDG/LungCancer_Subtyping/data/nifti/AKH_nifti_637/STARCH-JOHANN-DI20230810/PET.nii.gz
#     ct_path: /mnt/HDD_1/FDG/LungCancer_Subtyping/data/nifti/AKH_nifti_637/STARCH-JOHANN-DI20230810/CT.nii.gz
#     lung_seg_path: /mnt/HDD_1/FDG/LungCancer_Subtyping/data/processed_yaobo/lung_seg/AKH_nifti_637/STARCH-JOHANN-DI20230810/lung_seg.nii.gz
#     pet_exists: True
#     ct_exists: True
#     lung_seg_exists: True
#     SUV_ratio: 0.0005756709679489
#     Pathology: LCNEC
#   --------------------------------------------------
#
# ✓ 在原始metadata中找到: AKH_nifti_637/TORDAY-ILSE-MARIA20110308
# 对应的完整行信息:
#   行 567:
#     center: AKH_nifti_637
#     PID: TORDAY-ILSE-MARIA20110308
#     pet_path: /mnt/HDD_1/FDG/LungCancer_Subtyping/data/nifti/AKH_nifti_637/TORDAY-ILSE-MARIA20110308/PET.nii.gz
#     ct_path: /mnt/HDD_1/FDG/LungCancer_Subtyping/data/nifti/AKH_nifti_637/TORDAY-ILSE-MARIA20110308/CT.nii.gz
#     lung_seg_path: /mnt/HDD_1/FDG/LungCancer_Subtyping/data/processed_yaobo/lung_seg/AKH_nifti_637/TORDAY-ILSE-MARIA20110308/lung_seg.nii.gz
#     pet_exists: True
#     ct_exists: True
#     lung_seg_exists: True
#     SUV_ratio: 0.0002734440834767
#     Pathology: LCNEC
#   --------------------------------------------------
#
# ✓ 在原始metadata中找到: AKH_nifti_637/VASAROS-BRIGITTA20100315
# 对应的完整行信息:
#   行 581:
#     center: AKH_nifti_637
#     PID: VASAROS-BRIGITTA20100315
#     pet_path: /mnt/HDD_1/FDG/LungCancer_Subtyping/data/nifti/AKH_nifti_637/VASAROS-BRIGITTA20100315/PET.nii.gz
#     ct_path: /mnt/HDD_1/FDG/LungCancer_Subtyping/data/nifti/AKH_nifti_637/VASAROS-BRIGITTA20100315/CT.nii.gz
#     lung_seg_path: /mnt/HDD_1/FDG/LungCancer_Subtyping/data/processed_yaobo/lung_seg/AKH_nifti_637/VASAROS-BRIGITTA20100315/lung_seg.nii.gz
#     pet_exists: True
#     ct_exists: True
#     lung_seg_exists: True
#     SUV_ratio: 0.0003522269675685
#     Pathology: LCNEC
#   --------------------------------------------------
#
# ✓ 在原始metadata中找到: Neimeng_nifti_425/156
# 对应的完整行信息:
#   行 791:
#     center: Neimeng_nifti_425
#     PID: 156
#     pet_path: /mnt/HDD_1/FDG/LungCancer_Subtyping/data/nifti/Neimeng_nifti_425/156/PET.nii.gz
#     ct_path: /mnt/HDD_1/FDG/LungCancer_Subtyping/data/nifti/Neimeng_nifti_425/156/CT.nii.gz
#     lung_seg_path: /mnt/HDD_1/FDG/LungCancer_Subtyping/data/processed_yaobo/lung_seg/Neimeng_nifti_425/156/lung_seg.nii.gz
#     pet_exists: True
#     ct_exists: True
#     lung_seg_exists: True
#     SUV_ratio: 0.0003237397632815
#     Pathology: Sarcoma
#   --------------------------------------------------
#
# ✓ 在原始metadata中找到: Neimeng_nifti_425/257
# 对应的完整行信息:
#   行 893:
#     center: Neimeng_nifti_425
#     PID: 257
#     pet_path: /mnt/HDD_1/FDG/LungCancer_Subtyping/data/nifti/Neimeng_nifti_425/257/PET.nii.gz
#     ct_path: /mnt/HDD_1/FDG/LungCancer_Subtyping/data/nifti/Neimeng_nifti_425/257/CT.nii.gz
#     lung_seg_path: /mnt/HDD_1/FDG/LungCancer_Subtyping/data/processed_yaobo/lung_seg/Neimeng_nifti_425/257/lung_seg.nii.gz
#     pet_exists: True
#     ct_exists: True
#     lung_seg_exists: True
#     SUV_ratio: 0.0003026155879935
#     Pathology: Sarcoma
#   --------------------------------------------------
#
# ✓ 在原始metadata中找到: Neimeng_nifti_425/270
# 对应的完整行信息:
#   行 907:
#     center: Neimeng_nifti_425
#     PID: 270
#     pet_path: /mnt/HDD_1/FDG/LungCancer_Subtyping/data/nifti/Neimeng_nifti_425/270/PET.nii.gz
#     ct_path: /mnt/HDD_1/FDG/LungCancer_Subtyping/data/nifti/Neimeng_nifti_425/270/CT.nii.gz
#     lung_seg_path: /mnt/HDD_1/FDG/LungCancer_Subtyping/data/processed_yaobo/lung_seg/Neimeng_nifti_425/270/lung_seg.nii.gz
#     pet_exists: True
#     ct_exists: True
#     lung_seg_exists: True
#     SUV_ratio: 0.0003895704235705
#     Pathology: MEC
#   --------------------------------------------------
#
# ✓ 在原始metadata中找到: Neimeng_nifti_425/320
# 对应的完整行信息:
#   行 956:
#     center: Neimeng_nifti_425
#     PID: 320
#     pet_path: /mnt/HDD_1/FDG/LungCancer_Subtyping/data/nifti/Neimeng_nifti_425/320/PET.nii.gz
#     ct_path: /mnt/HDD_1/FDG/LungCancer_Subtyping/data/nifti/Neimeng_nifti_425/320/CT.nii.gz
#     lung_seg_path: /mnt/HDD_1/FDG/LungCancer_Subtyping/data/processed_yaobo/lung_seg/Neimeng_nifti_425/320/lung_seg.nii.gz
#     pet_exists: True
#     ct_exists: True
#     lung_seg_exists: True
#     SUV_ratio: 0.000340614914095
#     Pathology: ADC+SCC
#   --------------------------------------------------
#
# ✓ 在原始metadata中找到: Neimeng_nifti_425/406
# 对应的完整行信息:
#   行 1038:
#     center: Neimeng_nifti_425
#     PID: 406
#     pet_path: /mnt/HDD_1/FDG/LungCancer_Subtyping/data/nifti/Neimeng_nifti_425/406/PET.nii.gz
#     ct_path: /mnt/HDD_1/FDG/LungCancer_Subtyping/data/nifti/Neimeng_nifti_425/406/CT.nii.gz
#     lung_seg_path: /mnt/HDD_1/FDG/LungCancer_Subtyping/data/processed_yaobo/lung_seg/Neimeng_nifti_425/406/lung_seg.nii.gz
#     pet_exists: True
#     ct_exists: True
#     lung_seg_exists: True
#     SUV_ratio: 0.0003288406376852
#     Pathology: LCLC
#   --------------------------------------------------
#
# === 原始metadata查找结果汇总 ===
# 在原始metadata中找到的完整额外样本: 20
# 在原始metadata中未找到的完整额外样本: 0
#
# 找到的样本列表:
#   - AKH_nifti_637/AHAMER-GERHARD20240213
#   - AKH_nifti_637/CZERNY-JOHANN20190801
#   - AKH_nifti_637/ERISTAVI-DAVID20091022
#   - AKH_nifti_637/GEBAUER-GABRIELE20100929
#   - AKH_nifti_637/GINDL-PFLANZ-DIANA20230814
#   - AKH_nifti_637/GRUJA-LINA20230323
#   - AKH_nifti_637/HAJRULA-CENGIZ20210223
#   - AKH_nifti_637/HOBUSCH-DIETHARD20100817
#   - AKH_nifti_637/HOFER-EMMERICH20150224
#   - AKH_nifti_637/PUTZ-THERESIA20230831
#   - AKH_nifti_637/REINER-ERNST20220504
#   - AKH_nifti_637/SAVIC-PERO20090924
#   - AKH_nifti_637/STARCH-JOHANN-DI20230810
#   - AKH_nifti_637/TORDAY-ILSE-MARIA20110308
#   - AKH_nifti_637/VASAROS-BRIGITTA20100315
#   - Neimeng_nifti_425/156
#   - Neimeng_nifti_425/257
#   - Neimeng_nifti_425/270
#   - Neimeng_nifti_425/320
#   - Neimeng_nifti_425/406

# %% [markdown]
# Resample的文件中相比metadata_filtered.csv文件中的PID，多出20个，其中AKH多15个，Meimeng多5个。经过检查为metadata中，pathology为ADC、SCC、SCLC三个类别之外的subtyping，故排除。因此后续就以metadata_filtered.csv为核心目录处理数据。

# %% [markdown]
# ## 检查组间的spacing是否一致，检查组内的shape是否一致。

# %%
# 检查每个PID的四个模态数据的shape和spacing一致性
import pandas as pd
import numpy as np
import nibabel as nib
from pathlib import Path
from collections import defaultdict

def check_shape_spacing_consistency():
    """
    检查每个PID的四个模态数据的shape和spacing一致性
    """
    print("=== 检查重采样数据的shape和spacing一致性 ===")
    
    # 读取筛选后的metadata
    metadata_df = pd.read_csv("metadata/metadata_filtered.csv", dtype={'PID': str})
    
    print(f"需要检查的样本数: {len(metadata_df)}")
    
    # 定义目标spacing
    TARGET_SPACING = np.array([4.07283, 4.07283, 3.0])
    print(f"目标spacing: {TARGET_SPACING}")
    
    # 定义数据路径模板
    data_paths = {
        'CT': '/mnt/HDD_1/FDG/LungCancer_Subtyping/data/processed_yaobo/resampled_nifti/{center}/{pid}/CT.nii.gz',
        'PET': '/mnt/HDD_1/FDG/LungCancer_Subtyping/data/processed_yaobo/resampled_nifti/{center}/{pid}/PET.nii.gz',
        'lung_mask': '/mnt/HDD_1/FDG/LungCancer_Subtyping/data/processed_yaobo/lung_seg/{center}/{pid}/lung_seg.nii.gz',
        'lesion_mask': '/mnt/HDD_1/FDG/LungCancer_Subtyping/data/processed_yaobo/lesion_seg/{center}/{pid}/lesion_seg.nii.gz'
    }
    
    # 记录问题样本
    shape_inconsistent_samples = []
    spacing_incorrect_samples = []
    file_missing_samples = []
    
    print(f"\n=== 开始逐个检查样本 ===")
    
    for idx, row in metadata_df.iterrows():
        center = row['center']
        pid = row['PID']
        
        print(f"检查 {idx+1}/{len(metadata_df)}: {center}/{pid}", end="")
        
        # 加载四个模态的数据
        modality_data = {}
        sample_has_issues = False
        
        for modality, path_template in data_paths.items():
            file_path = path_template.format(center=center, pid=pid)
            
            if not os.path.exists(file_path):
                file_missing_samples.append({
                    'center': center,
                    'pid': pid,
                    'missing_modality': modality,
                    'file_path': file_path
                })
                print(f" - 缺少{modality}文件")
                sample_has_issues = True
                continue
            
            try:
                # 加载NIfTI文件
                nii_img = nib.load(file_path)
                img_data = nii_img.get_fdata()
                header = nii_img.header
                spacing = np.array(header.get_zooms())
                
                modality_data[modality] = {
                    'shape': img_data.shape,
                    'spacing': spacing,
                    'file_path': file_path
                }
                
            except Exception as e:
                print(f" - 读取{modality}文件错误: {e}")
                sample_has_issues = True
                continue
        
        if sample_has_issues:
            continue
        
        if len(modality_data) < 4:
            continue
            
        # 检查spacing一致性
        spacing_issues = []
        for modality, data in modality_data.items():
            if not np.allclose(data['spacing'], TARGET_SPACING, atol=1e-3):
                spacing_issues.append({
                    'modality': modality,
                    'actual_spacing': data['spacing'],
                    'target_spacing': TARGET_SPACING
                })
        
        if spacing_issues:
            spacing_incorrect_samples.append({
                'center': center,
                'pid': pid,
                'spacing_issues': spacing_issues
            })
        
        # 检查shape一致性
        shapes = [data['shape'] for data in modality_data.values()]
        modalities = list(modality_data.keys())
        
        if not all(shape == shapes[0] for shape in shapes):
            shape_info = []
            for i, (modality, data) in enumerate(modality_data.items()):
                shape_info.append({
                    'modality': modality,
                    'shape': data['shape']
                })
            
            shape_inconsistent_samples.append({
                'center': center,
                'pid': pid,
                'shape_info': shape_info
            })
        
        # 显示检查状态
        if spacing_issues or not all(shape == shapes[0] for shape in shapes):
            print(" - 有问题")
        else:
            print(" - OK")
    
    return shape_inconsistent_samples, spacing_incorrect_samples, file_missing_samples

# 执行检查
shape_issues, spacing_issues, missing_files = check_shape_spacing_consistency()
# Out:
# === 检查重采样数据的shape和spacing一致性 ===
# 需要检查的样本数: 1030
# 目标spacing: [4.07283 4.07283 3.     ]
#
# === 开始逐个检查样本 ===
# 检查 1/1030: AKH_nifti_637/ABDALLA-ADEL-AHMED20091023 - OK
# 检查 2/1030: AKH_nifti_637/ABT-BRIGITTE20160818 - OK
# 检查 3/1030: AKH_nifti_637/ADAMEK-KARIN20211124 - OK
# 检查 4/1030: AKH_nifti_637/AHMED-MOHAMED20230731 - OK
# 检查 5/1030: AKH_nifti_637/AHMEDI-NAZIF20230111 - OK
# 检查 6/1030: AKH_nifti_637/ALIMANY-RAMOS-MARIA20141007 - OK
# 检查 7/1030: AKH_nifti_637/ANDABAKA-MARIJAN20091229 - OK
# 检查 8/1030: AKH_nifti_637/ANSARI-MEHR-AZITA20141216 - OK
# 检查 9/1030: AKH_nifti_637/ANTIC-PRVOSLAV20150826 - OK
# 检查 10/1030: AKH_nifti_637/ANTIC-SLOBODAN20150908 - OK
# 检查 11/1030: AKH_nifti_637/ANVIEH-GOLPASHIN-DIANA20240108 - OK
# 检查 12/1030: AKH_nifti_637/ARNAUER-LEOPOLD20120820 - OK
# 检查 13/1030: AKH_nifti_637/ARSIC-DUSAN20120103 - OK
# 检查 14/1030: AKH_nifti_637/ARSLAN-SAMIL-DI20190715 - OK
# 检查 15/1030: AKH_nifti_637/ASCHENBRENNER-MARLENE20150430 - OK
# 检查 16/1030: AKH_nifti_637/AYDIN-ALI20220803 - OK
# 检查 617/1030: AKH_nifti_637/ZIMMERMANN-IRENE20121122 - OK
# 检查 618/1030: AKH_nifti_637/ZIMOLA-KARL20101220 - OK
# 检查 619/1030: Neimeng_nifti_425/001 - OK
# 检查 620/1030: Neimeng_nifti_425/002 - OK
# 检查 621/1030: Neimeng_nifti_425/003 - OK
# 检查 622/1030: Neimeng_nifti_425/004 - OK
# 检查 623/1030: Neimeng_nifti_425/005 - OK
# 检查 624/1030: Neimeng_nifti_425/006 - OK
# 检查 625/1030: Neimeng_nifti_425/007 - OK
# 检查 626/1030: Neimeng_nifti_425/009 - OK
# 检查 627/1030: Neimeng_nifti_425/010 - OK
# 检查 628/1030: Neimeng_nifti_425/011 - OK
# 检查 629/1030: Neimeng_nifti_425/012 - OK
# 检查 630/1030: Neimeng_nifti_425/013 - OK
# 检查 631/1030: Neimeng_nifti_425/014 - OK
# 检查 632/1030: Neimeng_nifti_425/015 - OK
# 检查 633/1030: Neimeng_nifti_425/016 - OK
# 检查 634/1030: Neimeng_nifti_425/017 - OK
# 检查 635/1030: Neimeng_nifti_425/018 - OK
# 检查 636/1030: Neimeng_nifti_425/019 - OK
# 检查 637/1030: Neimeng_nifti_425/020 - OK
# 检查 638/1030: Neimeng_nifti_425/021 - OK
# 检查 639/1030: Neimeng_nifti_425/022 - OK
# 检查 640/1030: Neimeng_nifti_425/023 - OK
# 检查 641/1030: Neimeng_nifti_425/024 - OK
# 检查 642/1030: Neimeng_nifti_425/025 - OK
# 检查 643/1030: Neimeng_nifti_425/026 - OK
# 检查 644/1030: Neimeng_nifti_425/027 - OK
# 检查 645/1030: Neimeng_nifti_425/028 - OK
# 检查 646/1030: Neimeng_nifti_425/029 - OK
# 检查 647/1030: Neimeng_nifti_425/031 - OK
# 检查 648/1030: Neimeng_nifti_425/032 - OK
# 检查 649/1030: Neimeng_nifti_425/033 - OK
# 检查 650/1030: Neimeng_nifti_425/034 - OK
# 检查 651/1030: Neimeng_nifti_425/035 - OK
# 检查 652/1030: Neimeng_nifti_425/036 - OK
# 检查 653/1030: Neimeng_nifti_425/037 - OK
# 检查 654/1030: Neimeng_nifti_425/038 - OK
# 检查 655/1030: Neimeng_nifti_425/039 - OK
# 检查 656/1030: Neimeng_nifti_425/040 - OK
# 检查 657/1030: Neimeng_nifti_425/041 - OK
# 检查 658/1030: Neimeng_nifti_425/042 - OK
# 检查 659/1030: Neimeng_nifti_425/043 - OK
# 检查 660/1030: Neimeng_nifti_425/044 - OK
# 检查 661/1030: Neimeng_nifti_425/045 - OK
# 检查 662/1030: Neimeng_nifti_425/046 - OK
# 检查 663/1030: Neimeng_nifti_425/047 - OK
# 检查 664/1030: Neimeng_nifti_425/048 - OK
# 检查 665/1030: Neimeng_nifti_425/049 - OK
# 检查 666/1030: Neimeng_nifti_425/050 - OK
# 检查 667/1030: Neimeng_nifti_425/054 - OK
# 检查 668/1030: Neimeng_nifti_425/055 - OK
# 检查 669/1030: Neimeng_nifti_425/056 - OK
# 检查 670/1030: Neimeng_nifti_425/057 - OK
# 检查 671/1030: Neimeng_nifti_425/058 - OK
# 检查 672/1030: Neimeng_nifti_425/059 - OK
# 检查 673/1030: Neimeng_nifti_425/060 - OK
# 检查 674/1030: Neimeng_nifti_425/061 - OK
# 检查 675/1030: Neimeng_nifti_425/062 - OK
# 检查 676/1030: Neimeng_nifti_425/063 - OK
# 检查 677/1030: Neimeng_nifti_425/064 - OK
# 检查 678/1030: Neimeng_nifti_425/065 - OK
# 检查 679/1030: Neimeng_nifti_425/066 - OK
# 检查 680/1030: Neimeng_nifti_425/067 - OK
# 检查 681/1030: Neimeng_nifti_425/068 - OK
# 检查 682/1030: Neimeng_nifti_425/069 - OK
# 检查 683/1030: Neimeng_nifti_425/070 - OK
# 检查 684/1030: Neimeng_nifti_425/071 - OK
# 检查 685/1030: Neimeng_nifti_425/072 - OK
# 检查 686/1030: Neimeng_nifti_425/073 - OK
# 检查 687/1030: Neimeng_nifti_425/074 - OK
# 检查 688/1030: Neimeng_nifti_425/075 - OK
# 检查 689/1030: Neimeng_nifti_425/076 - OK
# 检查 690/1030: Neimeng_nifti_425/077 - OK
# 检查 691/1030: Neimeng_nifti_425/078 - OK
# 检查 692/1030: Neimeng_nifti_425/079 - OK
# 检查 693/1030: Neimeng_nifti_425/080 - OK
# 检查 694/1030: Neimeng_nifti_425/081 - OK
# 检查 695/1030: Neimeng_nifti_425/082 - OK
# 检查 696/1030: Neimeng_nifti_425/083 - OK
# 检查 697/1030: Neimeng_nifti_425/085 - OK
# 检查 698/1030: Neimeng_nifti_425/087 - OK
# 检查 699/1030: Neimeng_nifti_425/088 - OK
# 检查 700/1030: Neimeng_nifti_425/089 - OK
# 检查 701/1030: Neimeng_nifti_425/090 - OK
# 检查 702/1030: Neimeng_nifti_425/091 - OK
# 检查 703/1030: Neimeng_nifti_425/092 - OK
# 检查 704/1030: Neimeng_nifti_425/093 - OK
# 检查 705/1030: Neimeng_nifti_425/094 - OK
# 检查 706/1030: Neimeng_nifti_425/095 - OK
# 检查 707/1030: Neimeng_nifti_425/096 - OK
# 检查 708/1030: Neimeng_nifti_425/097 - OK
# 检查 709/1030: Neimeng_nifti_425/098 - OK
# 检查 710/1030: Neimeng_nifti_425/099 - OK
# 检查 711/1030: Neimeng_nifti_425/100 - OK
# 检查 712/1030: Neimeng_nifti_425/101 - OK
# 检查 713/1030: Neimeng_nifti_425/102 - OK
# 检查 714/1030: Neimeng_nifti_425/103 - OK
# 检查 715/1030: Neimeng_nifti_425/104 - OK
# 检查 716/1030: Neimeng_nifti_425/105 - OK
# 检查 717/1030: Neimeng_nifti_425/106 - OK
# 检查 718/1030: Neimeng_nifti_425/107 - OK
# 检查 719/1030: Neimeng_nifti_425/108 - OK
# 检查 720/1030: Neimeng_nifti_425/109 - OK
# 检查 721/1030: Neimeng_nifti_425/110 - OK
# 检查 722/1030: Neimeng_nifti_425/111 - OK
# 检查 723/1030: Neimeng_nifti_425/112 - OK
# 检查 724/1030: Neimeng_nifti_425/113 - OK
# 检查 725/1030: Neimeng_nifti_425/114 - OK
# 检查 726/1030: Neimeng_nifti_425/115 - OK
# 检查 727/1030: Neimeng_nifti_425/116 - OK
# 检查 728/1030: Neimeng_nifti_425/117 - OK
# 检查 729/1030: Neimeng_nifti_425/118 - OK
# 检查 730/1030: Neimeng_nifti_425/119 - OK
# 检查 731/1030: Neimeng_nifti_425/120 - OK
# 检查 732/1030: Neimeng_nifti_425/121 - OK
# 检查 733/1030: Neimeng_nifti_425/122 - OK
# 检查 734/1030: Neimeng_nifti_425/123 - OK
# 检查 735/1030: Neimeng_nifti_425/124 - OK
# 检查 736/1030: Neimeng_nifti_425/125 - OK
# 检查 737/1030: Neimeng_nifti_425/126 - OK
# 检查 738/1030: Neimeng_nifti_425/127 - OK
# 检查 739/1030: Neimeng_nifti_425/128 - OK
# 检查 740/1030: Neimeng_nifti_425/129 - OK
# 检查 741/1030: Neimeng_nifti_425/130 - OK
# 检查 742/1030: Neimeng_nifti_425/131 - OK
# 检查 743/1030: Neimeng_nifti_425/132 - OK
# 检查 744/1030: Neimeng_nifti_425/133 - OK
# 检查 745/1030: Neimeng_nifti_425/134 - OK
# 检查 746/1030: Neimeng_nifti_425/135 - OK
# 检查 747/1030: Neimeng_nifti_425/136 - OK
# 检查 748/1030: Neimeng_nifti_425/137 - OK
# 检查 749/1030: Neimeng_nifti_425/138 - OK
# 检查 750/1030: Neimeng_nifti_425/139 - OK
# 检查 751/1030: Neimeng_nifti_425/140 - OK
# 检查 752/1030: Neimeng_nifti_425/141 - OK
# 检查 753/1030: Neimeng_nifti_425/142 - OK
# 检查 754/1030: Neimeng_nifti_425/143 - OK
# 检查 755/1030: Neimeng_nifti_425/144 - OK
# 检查 756/1030: Neimeng_nifti_425/145 - OK
# 检查 757/1030: Neimeng_nifti_425/146 - OK
# 检查 758/1030: Neimeng_nifti_425/147 - OK
# 检查 759/1030: Neimeng_nifti_425/148 - OK
# 检查 760/1030: Neimeng_nifti_425/149 - OK
# 检查 761/1030: Neimeng_nifti_425/150 - OK
# 检查 762/1030: Neimeng_nifti_425/151 - OK
# 检查 763/1030: Neimeng_nifti_425/152 - OK
# 检查 764/1030: Neimeng_nifti_425/153 - OK
# 检查 765/1030: Neimeng_nifti_425/154 - OK
# 检查 766/1030: Neimeng_nifti_425/155 - OK
# 检查 767/1030: Neimeng_nifti_425/158 - OK
# 检查 768/1030: Neimeng_nifti_425/159 - OK
# 检查 769/1030: Neimeng_nifti_425/160 - OK
# 检查 770/1030: Neimeng_nifti_425/161 - OK
# 检查 771/1030: Neimeng_nifti_425/162 - OK
# 检查 772/1030: Neimeng_nifti_425/163 - OK
# 检查 773/1030: Neimeng_nifti_425/164 - OK
# 检查 774/1030: Neimeng_nifti_425/165 - OK
# 检查 775/1030: Neimeng_nifti_425/167 - OK
# 检查 776/1030: Neimeng_nifti_425/168 - OK
# 检查 777/1030: Neimeng_nifti_425/169 - OK
# 检查 778/1030: Neimeng_nifti_425/170 - OK
# 检查 779/1030: Neimeng_nifti_425/171 - OK
# 检查 780/1030: Neimeng_nifti_425/172 - OK
# 检查 781/1030: Neimeng_nifti_425/173 - OK
# 检查 782/1030: Neimeng_nifti_425/174 - OK
# 检查 783/1030: Neimeng_nifti_425/175 - OK
# 检查 784/1030: Neimeng_nifti_425/177 - OK
# 检查 785/1030: Neimeng_nifti_425/178 - OK
# 检查 786/1030: Neimeng_nifti_425/179 - OK
# 检查 787/1030: Neimeng_nifti_425/180 - OK
# 检查 788/1030: Neimeng_nifti_425/181 - OK
# 检查 789/1030: Neimeng_nifti_425/182 - OK
# 检查 790/1030: Neimeng_nifti_425/183 - OK
# 检查 791/1030: Neimeng_nifti_425/184 - OK
# 检查 792/1030: Neimeng_nifti_425/185 - OK
# 检查 793/1030: Neimeng_nifti_425/186 - OK
# 检查 794/1030: Neimeng_nifti_425/187 - OK
# 检查 795/1030: Neimeng_nifti_425/188 - OK
# 检查 796/1030: Neimeng_nifti_425/189 - OK
# 检查 797/1030: Neimeng_nifti_425/190 - OK
# 检查 798/1030: Neimeng_nifti_425/191 - OK
# 检查 799/1030: Neimeng_nifti_425/192 - OK
# 检查 800/1030: Neimeng_nifti_425/193 - OK
# 检查 801/1030: Neimeng_nifti_425/194 - OK
# 检查 802/1030: Neimeng_nifti_425/195 - OK
# 检查 803/1030: Neimeng_nifti_425/196 - OK
# 检查 804/1030: Neimeng_nifti_425/197 - OK
# 检查 805/1030: Neimeng_nifti_425/198 - OK
# 检查 806/1030: Neimeng_nifti_425/199 - OK
# 检查 807/1030: Neimeng_nifti_425/200 - OK
# 检查 808/1030: Neimeng_nifti_425/201 - OK
# 检查 809/1030: Neimeng_nifti_425/202 - OK
# 检查 810/1030: Neimeng_nifti_425/203 - OK
# 检查 811/1030: Neimeng_nifti_425/204 - OK
# 检查 812/1030: Neimeng_nifti_425/205 - OK
# 检查 813/1030: Neimeng_nifti_425/206 - OK
# 检查 814/1030: Neimeng_nifti_425/207 - OK
# 检查 815/1030: Neimeng_nifti_425/208 - OK
# 检查 816/1030: Neimeng_nifti_425/209 - OK
# 检查 817/1030: Neimeng_nifti_425/210 - OK
# 检查 818/1030: Neimeng_nifti_425/211 - OK
# 检查 819/1030: Neimeng_nifti_425/212 - OK
# 检查 820/1030: Neimeng_nifti_425/213 - OK
# 检查 821/1030: Neimeng_nifti_425/214 - OK
# 检查 822/1030: Neimeng_nifti_425/215 - OK
# 检查 823/1030: Neimeng_nifti_425/216 - OK
# 检查 824/1030: Neimeng_nifti_425/217 - OK
# 检查 825/1030: Neimeng_nifti_425/218 - OK
# 检查 826/1030: Neimeng_nifti_425/219 - OK
# 检查 827/1030: Neimeng_nifti_425/220 - OK
# 检查 828/1030: Neimeng_nifti_425/221 - OK
# 检查 829/1030: Neimeng_nifti_425/222 - OK
# 检查 830/1030: Neimeng_nifti_425/223 - OK
# 检查 831/1030: Neimeng_nifti_425/224 - OK
# 检查 832/1030: Neimeng_nifti_425/225 - OK
# 检查 833/1030: Neimeng_nifti_425/226 - OK
# 检查 834/1030: Neimeng_nifti_425/227 - OK
# 检查 835/1030: Neimeng_nifti_425/228 - OK
# 检查 836/1030: Neimeng_nifti_425/229 - OK
# 检查 837/1030: Neimeng_nifti_425/230 - OK
# 检查 838/1030: Neimeng_nifti_425/231 - OK
# 检查 839/1030: Neimeng_nifti_425/232 - OK
# 检查 840/1030: Neimeng_nifti_425/233 - OK
# 检查 841/1030: Neimeng_nifti_425/234 - OK
# 检查 842/1030: Neimeng_nifti_425/235 - OK
# 检查 843/1030: Neimeng_nifti_425/236 - OK
# 检查 844/1030: Neimeng_nifti_425/237 - OK
# 检查 845/1030: Neimeng_nifti_425/238 - OK
# 检查 846/1030: Neimeng_nifti_425/239 - OK
# 检查 847/1030: Neimeng_nifti_425/240 - OK
# 检查 848/1030: Neimeng_nifti_425/241 - OK
# 检查 849/1030: Neimeng_nifti_425/242 - OK
# 检查 850/1030: Neimeng_nifti_425/243 - OK
# 检查 851/1030: Neimeng_nifti_425/244 - OK
# 检查 852/1030: Neimeng_nifti_425/245 - OK
# 检查 853/1030: Neimeng_nifti_425/246 - OK
# 检查 854/1030: Neimeng_nifti_425/247 - OK
# 检查 855/1030: Neimeng_nifti_425/248 - OK
# 检查 856/1030: Neimeng_nifti_425/249 - OK
# 检查 857/1030: Neimeng_nifti_425/250 - OK
# 检查 858/1030: Neimeng_nifti_425/251 - OK
# 检查 859/1030: Neimeng_nifti_425/252 - OK
# 检查 860/1030: Neimeng_nifti_425/253 - OK
# 检查 861/1030: Neimeng_nifti_425/254 - OK
# 检查 862/1030: Neimeng_nifti_425/255 - OK
# 检查 863/1030: Neimeng_nifti_425/256 - OK
# 检查 864/1030: Neimeng_nifti_425/258 - OK
# 检查 865/1030: Neimeng_nifti_425/259 - OK
# 检查 866/1030: Neimeng_nifti_425/260 - OK
# 检查 867/1030: Neimeng_nifti_425/261 - OK
# 检查 868/1030: Neimeng_nifti_425/262 - OK
# 检查 869/1030: Neimeng_nifti_425/263 - OK
# 检查 870/1030: Neimeng_nifti_425/264 - OK
# 检查 871/1030: Neimeng_nifti_425/266 - OK
# 检查 872/1030: Neimeng_nifti_425/267 - OK
# 检查 873/1030: Neimeng_nifti_425/268 - OK
# 检查 874/1030: Neimeng_nifti_425/269 - OK
# 检查 875/1030: Neimeng_nifti_425/271 - OK
# 检查 876/1030: Neimeng_nifti_425/272 - OK
# 检查 877/1030: Neimeng_nifti_425/273 - OK
# 检查 878/1030: Neimeng_nifti_425/274 - OK
# 检查 879/1030: Neimeng_nifti_425/275 - OK
# 检查 880/1030: Neimeng_nifti_425/276 - OK
# 检查 881/1030: Neimeng_nifti_425/277 - OK
# 检查 882/1030: Neimeng_nifti_425/278 - OK
# 检查 883/1030: Neimeng_nifti_425/279 - OK
# 检查 884/1030: Neimeng_nifti_425/280 - OK
# 检查 885/1030: Neimeng_nifti_425/281 - OK
# 检查 886/1030: Neimeng_nifti_425/282 - OK
# 检查 887/1030: Neimeng_nifti_425/283 - OK
# 检查 888/1030: Neimeng_nifti_425/284 - OK
# 检查 889/1030: Neimeng_nifti_425/285 - OK
# 检查 890/1030: Neimeng_nifti_425/286 - OK
# 检查 891/1030: Neimeng_nifti_425/288 - OK
# 检查 892/1030: Neimeng_nifti_425/289 - OK
# 检查 893/1030: Neimeng_nifti_425/290 - OK
# 检查 894/1030: Neimeng_nifti_425/291 - OK
# 检查 895/1030: Neimeng_nifti_425/292 - OK
# 检查 896/1030: Neimeng_nifti_425/293 - OK
# 检查 897/1030: Neimeng_nifti_425/294 - OK
# 检查 898/1030: Neimeng_nifti_425/295 - OK
# 检查 899/1030: Neimeng_nifti_425/296 - OK
# 检查 900/1030: Neimeng_nifti_425/297 - OK
# 检查 901/1030: Neimeng_nifti_425/298 - OK
# 检查 902/1030: Neimeng_nifti_425/299 - OK
# 检查 903/1030: Neimeng_nifti_425/300 - OK
# 检查 904/1030: Neimeng_nifti_425/301 - OK
# 检查 905/1030: Neimeng_nifti_425/302 - OK
# 检查 906/1030: Neimeng_nifti_425/303 - OK
# 检查 907/1030: Neimeng_nifti_425/304 - OK
# 检查 908/1030: Neimeng_nifti_425/305 - OK
# 检查 909/1030: Neimeng_nifti_425/306 - OK
# 检查 910/1030: Neimeng_nifti_425/307 - OK
# 检查 911/1030: Neimeng_nifti_425/308 - OK
# 检查 912/1030: Neimeng_nifti_425/309 - OK
# 检查 913/1030: Neimeng_nifti_425/310 - OK
# 检查 914/1030: Neimeng_nifti_425/311 - OK
# 检查 915/1030: Neimeng_nifti_425/312 - OK
# 检查 916/1030: Neimeng_nifti_425/313 - OK
# 检查 917/1030: Neimeng_nifti_425/314 - OK
# 检查 918/1030: Neimeng_nifti_425/315 - OK
# 检查 919/1030: Neimeng_nifti_425/316 - OK
# 检查 920/1030: Neimeng_nifti_425/317 - OK
# 检查 921/1030: Neimeng_nifti_425/318 - OK
# 检查 922/1030: Neimeng_nifti_425/319 - OK
# 检查 923/1030: Neimeng_nifti_425/321 - OK
# 检查 924/1030: Neimeng_nifti_425/322 - OK
# 检查 925/1030: Neimeng_nifti_425/323 - OK
# 检查 926/1030: Neimeng_nifti_425/324 - OK
# 检查 927/1030: Neimeng_nifti_425/325 - OK
# 检查 928/1030: Neimeng_nifti_425/326 - OK
# 检查 929/1030: Neimeng_nifti_425/327 - OK
# 检查 930/1030: Neimeng_nifti_425/328 - OK
# 检查 931/1030: Neimeng_nifti_425/329 - OK
# 检查 932/1030: Neimeng_nifti_425/330 - OK
# 检查 933/1030: Neimeng_nifti_425/331 - OK
# 检查 934/1030: Neimeng_nifti_425/332 - OK
# 检查 935/1030: Neimeng_nifti_425/333 - OK
# 检查 936/1030: Neimeng_nifti_425/334 - OK
# 检查 937/1030: Neimeng_nifti_425/335 - OK
# 检查 938/1030: Neimeng_nifti_425/336 - OK
# 检查 939/1030: Neimeng_nifti_425/337 - OK
# 检查 940/1030: Neimeng_nifti_425/338 - OK
# 检查 941/1030: Neimeng_nifti_425/339 - OK
# 检查 942/1030: Neimeng_nifti_425/340 - OK
# 检查 943/1030: Neimeng_nifti_425/341 - OK
# 检查 944/1030: Neimeng_nifti_425/342 - OK
# 检查 945/1030: Neimeng_nifti_425/343 - OK
# 检查 946/1030: Neimeng_nifti_425/344 - OK
# 检查 947/1030: Neimeng_nifti_425/345 - OK
# 检查 948/1030: Neimeng_nifti_425/346 - OK
# 检查 949/1030: Neimeng_nifti_425/347 - OK
# 检查 950/1030: Neimeng_nifti_425/348 - OK
# 检查 951/1030: Neimeng_nifti_425/349 - OK
# 检查 952/1030: Neimeng_nifti_425/350 - OK
# 检查 953/1030: Neimeng_nifti_425/351 - OK
# 检查 954/1030: Neimeng_nifti_425/352 - OK
# 检查 955/1030: Neimeng_nifti_425/353 - OK
# 检查 956/1030: Neimeng_nifti_425/355 - OK
# 检查 957/1030: Neimeng_nifti_425/357 - OK
# 检查 958/1030: Neimeng_nifti_425/358 - OK
# 检查 959/1030: Neimeng_nifti_425/359 - OK
# 检查 960/1030: Neimeng_nifti_425/360 - OK
# 检查 961/1030: Neimeng_nifti_425/361 - OK
# 检查 962/1030: Neimeng_nifti_425/362 - OK
# 检查 963/1030: Neimeng_nifti_425/363 - OK
# 检查 964/1030: Neimeng_nifti_425/365 - OK
# 检查 965/1030: Neimeng_nifti_425/366 - OK
# 检查 966/1030: Neimeng_nifti_425/367 - OK
# 检查 967/1030: Neimeng_nifti_425/369 - OK
# 检查 968/1030: Neimeng_nifti_425/370 - OK
# 检查 969/1030: Neimeng_nifti_425/371 - OK
# 检查 970/1030: Neimeng_nifti_425/372 - OK
# 检查 971/1030: Neimeng_nifti_425/373 - OK
# 检查 972/1030: Neimeng_nifti_425/374 - OK
# 检查 973/1030: Neimeng_nifti_425/375 - OK
# 检查 974/1030: Neimeng_nifti_425/376 - OK
# 检查 975/1030: Neimeng_nifti_425/377 - OK
# 检查 976/1030: Neimeng_nifti_425/378 - OK
# 检查 977/1030: Neimeng_nifti_425/379 - OK
# 检查 978/1030: Neimeng_nifti_425/380 - OK
# 检查 979/1030: Neimeng_nifti_425/381 - OK
# 检查 980/1030: Neimeng_nifti_425/382 - OK
# 检查 981/1030: Neimeng_nifti_425/383 - OK
# 检查 982/1030: Neimeng_nifti_425/384 - OK
# 检查 983/1030: Neimeng_nifti_425/385 - OK
# 检查 984/1030: Neimeng_nifti_425/386 - OK
# 检查 985/1030: Neimeng_nifti_425/387 - OK
# 检查 986/1030: Neimeng_nifti_425/388 - OK
# 检查 987/1030: Neimeng_nifti_425/389 - OK
# 检查 988/1030: Neimeng_nifti_425/390 - OK
# 检查 989/1030: Neimeng_nifti_425/391 - OK
# 检查 990/1030: Neimeng_nifti_425/392 - OK
# 检查 991/1030: Neimeng_nifti_425/393 - OK
# 检查 992/1030: Neimeng_nifti_425/394 - OK
# 检查 993/1030: Neimeng_nifti_425/395 - OK
# 检查 994/1030: Neimeng_nifti_425/396 - OK
# 检查 995/1030: Neimeng_nifti_425/397 - OK
# 检查 996/1030: Neimeng_nifti_425/398 - OK
# 检查 997/1030: Neimeng_nifti_425/399 - OK
# 检查 998/1030: Neimeng_nifti_425/400 - OK
# 检查 999/1030: Neimeng_nifti_425/401 - OK
# 检查 1000/1030: Neimeng_nifti_425/402 - OK
# 检查 1001/1030: Neimeng_nifti_425/403 - OK
# 检查 1002/1030: Neimeng_nifti_425/404 - OK
# 检查 1003/1030: Neimeng_nifti_425/405 - OK
# 检查 1004/1030: Neimeng_nifti_425/407 - OK
# 检查 1005/1030: Neimeng_nifti_425/409 - OK
# 检查 1006/1030: Neimeng_nifti_425/411 - OK
# 检查 1007/1030: Neimeng_nifti_425/412 - OK
# 检查 1008/1030: Neimeng_nifti_425/413 - OK
# 检查 1009/1030: Neimeng_nifti_425/414 - OK
# 检查 1010/1030: Neimeng_nifti_425/415 - OK
# 检查 1011/1030: Neimeng_nifti_425/417 - OK
# 检查 1012/1030: Neimeng_nifti_425/418 - OK
# 检查 1013/1030: Neimeng_nifti_425/419 - OK
# 检查 1014/1030: Neimeng_nifti_425/420 - OK
# 检查 1015/1030: Neimeng_nifti_425/421 - OK
# 检查 1016/1030: Neimeng_nifti_425/422 - OK
# 检查 1017/1030: Neimeng_nifti_425/423 - OK
# 检查 1018/1030: Neimeng_nifti_425/424 - OK
# 检查 1019/1030: Neimeng_nifti_425/425 - OK
# 检查 1020/1030: Neimeng_nifti_425/426 - OK
# 检查 1021/1030: Neimeng_nifti_425/427 - OK
# 检查 1022/1030: Neimeng_nifti_425/428 - OK
# 检查 1023/1030: Neimeng_nifti_425/429 - OK
# 检查 1024/1030: Neimeng_nifti_425/430 - OK
# 检查 1025/1030: Neimeng_nifti_425/431 - OK
# 检查 1026/1030: Neimeng_nifti_425/432 - OK
# 检查 1027/1030: Neimeng_nifti_425/433 - OK
# 检查 1028/1030: Neimeng_nifti_425/434 - OK
# 检查 1029/1030: Neimeng_nifti_425/435 - OK
# 检查 1030/1030: Neimeng_nifti_425/437 - OK

# %%
# 生成详细的检查结果报告
def generate_consistency_report(shape_issues, spacing_issues, missing_files):
    """
    生成详细的shape和spacing一致性检查报告
    """
    print("\n" + "="*60)
    print("             数据一致性检查结果汇总")
    print("="*60)
    
    # 总体统计
    total_samples = len(pd.read_csv("metadata/metadata_filtered.csv"))
    
    print(f"\n1. 总体统计:")
    print(f"   - 检查的总样本数: {total_samples}")
    print(f"   - 文件缺失问题: {len(missing_files)} 个样本")
    print(f"   - Shape不一致问题: {len(shape_issues)} 个样本")
    print(f"   - Spacing不正确问题: {len(spacing_issues)} 个样本")
    
    successful_samples = total_samples - len(set(
        [f"{item['center']}/{item['pid']}" for item in missing_files] +
        [f"{item['center']}/{item['pid']}" for item in shape_issues] +
        [f"{item['center']}/{item['pid']}" for item in spacing_issues]
    ))
    
    print(f"   - 完全正确的样本: {successful_samples} ({successful_samples/total_samples*100:.1f}%)")
    
    # 详细报告
    if missing_files:
        print(f"\n2. 文件缺失问题详情:")
        missing_by_sample = defaultdict(list)
        for item in missing_files:
            key = f"{item['center']}/{item['pid']}"
            missing_by_sample[key].append(item['missing_modality'])
        
        for sample, missing_modalities in missing_by_sample.items():
            print(f"   - {sample}: 缺少 {', '.join(missing_modalities)}")
    
    if shape_issues:
        print(f"\n3. Shape不一致问题详情:")
        for item in shape_issues:
            sample = f"{item['center']}/{item['pid']}"
            print(f"   - {sample}:")
            for shape_info in item['shape_info']:
                print(f"     {shape_info['modality']}: {shape_info['shape']}")
    
    if spacing_issues:
        print(f"\n4. Spacing不正确问题详情:")
        for item in spacing_issues:
            sample = f"{item['center']}/{item['pid']}"
            print(f"   - {sample}:")
            for spacing_issue in item['spacing_issues']:
                modality = spacing_issue['modality']
                actual = spacing_issue['actual_spacing']
                target = spacing_issue['target_spacing']
                print(f"     {modality}: 实际 {actual} vs 目标 {target}")
    
    # 生成CSV报告
    print(f"\n5. 生成详细报告文件:")
    
    # Shape一致性报告
    if shape_issues:
        shape_report_data = []
        for item in shape_issues:
            for shape_info in item['shape_info']:
                shape_report_data.append({
                    'center': item['center'],
                    'PID': item['pid'],
                    'modality': shape_info['modality'],
                    'shape': str(shape_info['shape']),
                    'issue_type': 'shape_inconsistent'
                })
        
        shape_df = pd.DataFrame(shape_report_data)
        shape_report_path = "metadata/shape_consistency_issues.csv"
        shape_df.to_csv(shape_report_path, index=False)
        print(f"   ✓ Shape不一致报告: {shape_report_path}")
    
    # Spacing正确性报告
    if spacing_issues:
        spacing_report_data = []
        for item in spacing_issues:
            for spacing_issue in item['spacing_issues']:
                spacing_report_data.append({
                    'center': item['center'],
                    'PID': item['pid'],
                    'modality': spacing_issue['modality'],
                    'actual_spacing': str(spacing_issue['actual_spacing']),
                    'target_spacing': str(spacing_issue['target_spacing']),
                    'issue_type': 'spacing_incorrect'
                })
        
        spacing_df = pd.DataFrame(spacing_report_data)
        spacing_report_path = "metadata/spacing_consistency_issues.csv"
        spacing_df.to_csv(spacing_report_path, index=False)
        print(f"   ✓ Spacing不正确报告: {spacing_report_path}")
    
    # 文件缺失报告
    if missing_files:
        missing_df = pd.DataFrame(missing_files)
        missing_report_path = "metadata/missing_files_issues.csv"
        missing_df.to_csv(missing_report_path, index=False)
        print(f"   ✓ 文件缺失报告: {missing_report_path}")
    
    # 综合状态报告
    all_samples_status = []
    metadata_df = pd.read_csv("metadata/metadata_filtered.csv", dtype={'PID': str})
    
    # 创建问题样本集合
    missing_samples = set(f"{item['center']}/{item['pid']}" for item in missing_files)
    shape_problem_samples = set(f"{item['center']}/{item['pid']}" for item in shape_issues)
    spacing_problem_samples = set(f"{item['center']}/{item['pid']}" for item in spacing_issues)
    
    for _, row in metadata_df.iterrows():
        sample_key = f"{row['center']}/{row['PID']}"
        
        issues = []
        if sample_key in missing_samples:
            issues.append('missing_files')
        if sample_key in shape_problem_samples:
            issues.append('shape_inconsistent')
        if sample_key in spacing_problem_samples:
            issues.append('spacing_incorrect')
        
        all_samples_status.append({
            'center': row['center'],
            'PID': row['PID'],
            'status': 'OK' if not issues else 'ISSUES',
            'issues': ', '.join(issues) if issues else ''
        })
    
    status_df = pd.DataFrame(all_samples_status)
    status_report_path = "metadata/data_consistency_status.csv"
    status_df.to_csv(status_report_path, index=False)
    print(f"   ✓ 综合状态报告: {status_report_path}")
    
    print(f"\n6. 总结:")
    if not shape_issues and not spacing_issues and not missing_files:
        print("   🎉 所有数据都通过一致性检查！")
    else:
        print("   ⚠️  发现数据一致性问题，请查看详细报告文件")
    
    return status_df

# 生成报告
consistency_status = generate_consistency_report(shape_issues, spacing_issues, missing_files)
# Out:
# ============================================================
#              数据一致性检查结果汇总
# ============================================================
#
# 1. 总体统计:
#    - 检查的总样本数: 1030
#    - 文件缺失问题: 0 个样本
#    - Shape不一致问题: 0 个样本
#    - Spacing不正确问题: 0 个样本
#    - 完全正确的样本: 1030 (100.0%)
#
# 5. 生成详细报告文件:
#    ✓ 综合状态报告: metadata/data_consistency_status.csv
#
# 6. 总结:
#    🎉 所有数据都通过一致性检查！

# %%
# 验证检查结果并显示统计信息
def verify_and_show_stats():
    """
    验证检查结果并显示一些样本的统计信息
    """
    print("=== 验证检查结果 ===")
    
    # 读取状态报告
    status_df = pd.read_csv("metadata/data_consistency_status.csv", dtype={'PID': str})
    
    print(f"状态报告中的样本数: {len(status_df)}")
    print(f"状态分布:")
    print(status_df['status'].value_counts())
    
    # 随机选择几个样本进行详细验证
    print(f"\n=== 随机抽样验证 ===")
    
    # 从每个中心随机选择2个样本进行详细检查
    sample_data = []
    
    for center in ['AKH_nifti_637', 'Neimeng_nifti_425']:
        center_samples = status_df[status_df['center'] == center].sample(2, random_state=42)
        
        for _, row in center_samples.iterrows():
            pid = row['PID']
            print(f"\n验证样本: {center}/{pid}")
            
            # 定义数据路径
            data_paths = {
                'CT': f'/mnt/HDD_1/FDG/LungCancer_Subtyping/data/processed_yaobo/resampled_nifti/{center}/{pid}/CT.nii.gz',
                'PET': f'/mnt/HDD_1/FDG/LungCancer_Subtyping/data/processed_yaobo/resampled_nifti/{center}/{pid}/PET.nii.gz',
                'lung_mask': f'/mnt/HDD_1/FDG/LungCancer_Subtyping/data/processed_yaobo/lung_seg/{center}/{pid}/lung_seg.nii.gz',
                'lesion_mask': f'/mnt/HDD_1/FDG/LungCancer_Subtyping/data/processed_yaobo/lesion_seg/{center}/{pid}/lesion_seg.nii.gz'
            }
            
            sample_info = {'center': center, 'pid': pid}
            shapes = []
            spacings = []
            
            for modality, file_path in data_paths.items():
                if os.path.exists(file_path):
                    nii_img = nib.load(file_path)
                    img_data = nii_img.get_fdata()
                    spacing = nii_img.header.get_zooms()
                    
                    print(f"  {modality}: shape={img_data.shape}, spacing={np.round(spacing, 5)}")
                    shapes.append(img_data.shape)
                    spacings.append(spacing)
                    
                    sample_info[f'{modality}_shape'] = img_data.shape
                    sample_info[f'{modality}_spacing'] = spacing
                else:
                    print(f"  {modality}: 文件不存在")
            
            # 检查shape一致性
            if len(set(shapes)) == 1:
                print(f"  ✓ Shape一致: {shapes[0]}")
            else:
                print(f"  ✗ Shape不一致: {shapes}")
            
            # 检查spacing一致性
            target_spacing = np.array([4.07283, 4.07283, 3.0])
            all_spacing_correct = all(np.allclose(s, target_spacing, atol=1e-3) for s in spacings)
            
            if all_spacing_correct:
                print(f"  ✓ Spacing正确: 所有模态都为 {target_spacing}")
            else:
                print(f"  ✗ Spacing不正确")
                for i, s in enumerate(spacings):
                    print(f"    模态{i}: {s}")
            
            sample_data.append(sample_info)
    
    # 显示整体统计
    print(f"\n=== 整体数据统计 ===")
    
    # 按中心统计
    center_stats = status_df.groupby('center').size()
    print(f"各中心样本数:")
    for center, count in center_stats.items():
        print(f"  {center}: {count} 个样本")
    
    # 如果有问题样本，显示统计
    problem_samples = status_df[status_df['status'] != 'OK']
    if len(problem_samples) > 0:
        print(f"\n有问题的样本:")
        print(problem_samples)
    else:
        print(f"\n✓ 所有 {len(status_df)} 个样本都通过了一致性检查")
    
    return sample_data

# 执行验证
verification_data = verify_and_show_stats()
# Out:
# === 验证检查结果 ===
# 状态报告中的样本数: 1030
# 状态分布:
# status
# OK    1030
# Name: count, dtype: int64
#
# === 随机抽样验证 ===
#
# 验证样本: AKH_nifti_637/BRUKIC-MISA20210317
#   CT: shape=(153, 153, 374), spacing=[4.07283 4.07283 3.     ]
#   PET: shape=(153, 153, 374), spacing=[4.07283 4.07283 3.     ]
#   lung_mask: shape=(153, 153, 374), spacing=[4.07283 4.07283 3.     ]
#   lesion_mask: shape=(153, 153, 374), spacing=[4.07283 4.07283 3.     ]
#   ✓ Shape一致: (153, 153, 374)
#   ✓ Spacing正确: 所有模态都为 [4.07283 4.07283 3.     ]
#
# 验证样本: AKH_nifti_637/WEIDEMANN-MICHAEL20211019
#   CT: shape=(175, 175, 323), spacing=[4.07283 4.07283 3.     ]
#   PET: shape=(175, 175, 323), spacing=[4.07283 4.07283 3.     ]
#   lung_mask: shape=(175, 175, 323), spacing=[4.07283 4.07283 3.     ]
#   lesion_mask: shape=(175, 175, 323), spacing=[4.07283 4.07283 3.     ]
#   ✓ Shape一致: (175, 175, 323)
#   ✓ Spacing正确: 所有模态都为 [4.07283 4.07283 3.     ]
#
# 验证样本: Neimeng_nifti_425/288
#   CT: shape=(123, 123, 290), spacing=[4.07283 4.07283 3.     ]
#   PET: shape=(123, 123, 290), spacing=[4.07283 4.07283 3.     ]
#   lung_mask: shape=(123, 123, 290), spacing=[4.07283 4.07283 3.     ]
#   lesion_mask: shape=(123, 123, 290), spacing=[4.07283 4.07283 3.     ]
#   ✓ Shape一致: (123, 123, 290)
#   ✓ Spacing正确: 所有模态都为 [4.07283 4.07283 3.     ]
#
# 验证样本: Neimeng_nifti_425/061
#   CT: shape=(123, 123, 307), spacing=[4.07283 4.07283 3.     ]
#   PET: shape=(123, 123, 307), spacing=[4.07283 4.07283 3.     ]
#   lung_mask: shape=(123, 123, 307), spacing=[4.07283 4.07283 3.     ]
#   lesion_mask: shape=(123, 123, 307), spacing=[4.07283 4.07283 3.     ]
#   ✓ Shape一致: (123, 123, 307)
#   ✓ Spacing正确: 所有模态都为 [4.07283 4.07283 3.     ]
#
# === 整体数据统计 ===
# 各中心样本数:
#   AKH_nifti_637: 618 个样本
#   Neimeng_nifti_425: 412 个样本
#
# ✓ 所有 1030 个样本都通过了一致性检查
